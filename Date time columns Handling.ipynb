# %%
import numpy as np
import pandas as pd

# %%
date = pd.read_csv('orders.csv')
time = pd.read_csv('messages.csv')

# %%
date.head()
# Out:
#          date  product_id  city_id  orders
# 0  2019-12-10        5628       25       3
# 1  2018-08-15        3646       14     157
# 2  2018-10-23        1859       25       1
# 3  2019-08-17        7292       25       1
# 4  2019-01-06        4344       25       3

# %%
time.head()
# Out:
#                   date                                                msg
# 0  2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1  2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2  2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3  2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4  2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше

# %%
date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1000 non-null   object
#  1   product_id  1000 non-null   int64
#  2   city_id     1000 non-null   int64
#  3   orders      1000 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 31.4+ KB

# %%
#converting object to date time
date['date'] = pd.to_datetime(date['date'])

# %%
date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1000 non-null   datetime64[ns]
#  1   product_id  1000 non-null   int64
#  2   city_id     1000 non-null   int64
#  3   orders      1000 non-null   int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 31.4 KB

# %%
# extract year
date['date_year'] = date['date'].dt.year
date.head()
# Out:
#         date  product_id  city_id  orders  date_year  date_month  \
# 0 2019-12-10        5628       25       3       2019          12
# 1 2018-08-15        3646       14     157       2018           8
# 2 2018-10-23        1859       25       1       2018          10
# 3 2019-08-17        7292       25       1       2019           8
# 4 2019-01-06        4344       25       3       2019           1
#
#                                           month_name date_month_name
# 0  <bound method PandasDelegate._add_delegate_acc...        December
# 1  <bound method PandasDelegate._add_delegate_acc...          August
# 2  <bound method PandasDelegate._add_delegate_acc...         October
# 3  <bound method PandasDelegate._add_delegate_acc...          August
# 4  <bound method PandasDelegate._add_delegate_acc...         January

# %%
#extract month
date['date_month_no'] = date['date'].dt.month
date.head()
# Out:
#         date  product_id  city_id  orders  date_year  date_month  \
# 0 2019-12-10        5628       25       3       2019          12
# 1 2018-08-15        3646       14     157       2018           8
# 2 2018-10-23        1859       25       1       2018          10
# 3 2019-08-17        7292       25       1       2019           8
# 4 2019-01-06        4344       25       3       2019           1
#
#                                           month_name date_month_name  \
# 0  <bound method PandasDelegate._add_delegate_acc...        December
# 1  <bound method PandasDelegate._add_delegate_acc...          August
# 2  <bound method PandasDelegate._add_delegate_acc...         October
# 3  <bound method PandasDelegate._add_delegate_acc...          August
# 4  <bound method PandasDelegate._add_delegate_acc...         January
#
#    date_month_no
# 0             12
# 1              8
# 2             10
# 3              8
# 4              1

# %%
#extract month name
date['date_month_name'] = date['date'].dt.month_name()
date.head()
# Out:
#         date  product_id  city_id  orders  date_year  date_month  \
# 0 2019-12-10        5628       25       3       2019          12
# 1 2018-08-15        3646       14     157       2018           8
# 2 2018-10-23        1859       25       1       2018          10
# 3 2019-08-17        7292       25       1       2019           8
# 4 2019-01-06        4344       25       3       2019           1
#
#                                           month_name date_month_name  \
# 0  <bound method PandasDelegate._add_delegate_acc...        December
# 1  <bound method PandasDelegate._add_delegate_acc...          August
# 2  <bound method PandasDelegate._add_delegate_acc...         October
# 3  <bound method PandasDelegate._add_delegate_acc...          August
# 4  <bound method PandasDelegate._add_delegate_acc...         January
#
#    date_month_no
# 0             12
# 1              8
# 2             10
# 3              8
# 4              1

# %%
# extract days
date['date_day'] = date['date'].dt.day
date.head()
# Out:
#         date  product_id  city_id  orders  date_year  date_month  \
# 0 2019-12-10        5628       25       3       2019          12
# 1 2018-08-15        3646       14     157       2018           8
# 2 2018-10-23        1859       25       1       2018          10
# 3 2019-08-17        7292       25       1       2019           8
# 4 2019-01-06        4344       25       3       2019           1
#
#                                           month_name date_month_name  \
# 0  <bound method PandasDelegate._add_delegate_acc...        December
# 1  <bound method PandasDelegate._add_delegate_acc...          August
# 2  <bound method PandasDelegate._add_delegate_acc...         October
# 3  <bound method PandasDelegate._add_delegate_acc...          August
# 4  <bound method PandasDelegate._add_delegate_acc...         January
#
#    date_month_no  date_day
# 0             12        10
# 1              8        15
# 2             10        23
# 3              8        17
# 4              1         6

# %%
#extract day of week
date['date_week'] = date['date'].dt.dayofweek
date.head()
# Out:
#         date  product_id  city_id  orders  date_year  date_month  \
# 0 2019-12-10        5628       25       3       2019          12
# 1 2018-08-15        3646       14     157       2018           8
# 2 2018-10-23        1859       25       1       2018          10
# 3 2019-08-17        7292       25       1       2019           8
# 4 2019-01-06        4344       25       3       2019           1
#
#                                           month_name date_month_name  \
# 0  <bound method PandasDelegate._add_delegate_acc...        December
# 1  <bound method PandasDelegate._add_delegate_acc...          August
# 2  <bound method PandasDelegate._add_delegate_acc...         October
# 3  <bound method PandasDelegate._add_delegate_acc...          August
# 4  <bound method PandasDelegate._add_delegate_acc...         January
#
#    date_month_no  date_day  date_week
# 0             12        10          1
# 1              8        15          2
# 2             10        23          1
# 3              8        17          5
# 4              1         6          6

# %%
date['date_day_name'] = date['date'].dt.day_name()
date.head()
# Out:
#         date  product_id  city_id  orders  date_year  date_month  \
# 0 2019-12-10        5628       25       3       2019          12
# 1 2018-08-15        3646       14     157       2018           8
# 2 2018-10-23        1859       25       1       2018          10
# 3 2019-08-17        7292       25       1       2019           8
# 4 2019-01-06        4344       25       3       2019           1
#
#                                           month_name date_month_name  \
# 0  <bound method PandasDelegate._add_delegate_acc...        December
# 1  <bound method PandasDelegate._add_delegate_acc...          August
# 2  <bound method PandasDelegate._add_delegate_acc...         October
# 3  <bound method PandasDelegate._add_delegate_acc...          August
# 4  <bound method PandasDelegate._add_delegate_acc...         January
#
#    date_month_no  date_day  date_week date_day_name
# 0             12        10          1       Tuesday
# 1              8        15          2     Wednesday
# 2             10        23          1       Tuesday
# 3              8        17          5      Saturday
# 4              1         6          6        Sunday

# %%
date['date_is_week'] = np.where(date['date'].isin(['Sunday','Saturday']), 1,0)

# %%
date['quarter'] = date['date'].dt.quarter
date.head()
# Out:
#         date  product_id  city_id  orders  date_year  date_month  \
# 0 2019-12-10        5628       25       3       2019          12
# 1 2018-08-15        3646       14     157       2018           8
# 2 2018-10-23        1859       25       1       2018          10
# 3 2019-08-17        7292       25       1       2019           8
# 4 2019-01-06        4344       25       3       2019           1
#
#                                           month_name date_month_name  \
# 0  <bound method PandasDelegate._add_delegate_acc...        December
# 1  <bound method PandasDelegate._add_delegate_acc...          August
# 2  <bound method PandasDelegate._add_delegate_acc...         October
# 3  <bound method PandasDelegate._add_delegate_acc...          August
# 4  <bound method PandasDelegate._add_delegate_acc...         January
#
#    date_month_no  date_day  date_week date_day_name  date_is_week  quarter
# 0             12        10          1       Tuesday             0        4
# 1              8        15          2     Wednesday             0        3
# 2             10        23          1       Tuesday             0        4
# 3              8        17          5      Saturday             0        3
# 4              1         6          6        Sunday             0        1

# %%
#extract time 
import datetime
today = datetime.datetime.today()
today
# Out:
# datetime.datetime(2025, 7, 16, 15, 11, 52, 892946)

# %%
today - date['date']
# Out:
# 0     2045 days 15:11:52.892946
# 1     2527 days 15:11:52.892946
# 2     2458 days 15:11:52.892946
# 3     2160 days 15:11:52.892946
# 4     2383 days 15:11:52.892946
#                  ...
# 995   2473 days 15:11:52.892946
# 996   2414 days 15:11:52.892946
# 997   2262 days 15:11:52.892946
# 998   2327 days 15:11:52.892946
# 999   2101 days 15:11:52.892946
# Name: date, Length: 1000, dtype: timedelta64[ns]

# %%
time ['date'] = pd.to_datetime(time['date'])

# %%
time.head()
# Out:
#                  date                                                msg
# 0 2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1 2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2 2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3 2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4 2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше

# %%
time['hour'] = time['date'].dt.hour
time['min'] = time['date'].dt.minute
time['sec'] = time['date'].dt.second
time.head()
# Out:
#                  date                                                msg  \
# 0 2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1 2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2 2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3 2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4 2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше
#
#    hour  min  sec
# 0     0   50    0
# 1    23   40    0
# 2     0   21    0
# 3     0   31    0
# 4    23   11    0

# %%
today - time['date']
# Out:
# 0     4231 days 14:21:52.892946
# 1     4095 days 15:31:52.892946
# 2     4581 days 14:50:52.892946
# 3     3883 days 14:40:52.892946
# 4     4280 days 16:00:52.892946
#                  ...
# 995   4870 days 14:21:52.892946
# 996   4191 days 15:57:52.892946
# 997   4656 days 15:34:52.892946
# 998   4772 days 15:37:52.892946
# 999   4044 days 15:46:52.892946
# Name: date, Length: 1000, dtype: timedelta64[ns]

# %%
(today - time['date'])/np.timedelta64(1,'m')
# Out:
# 0      6.093502e+06
# 1      5.897732e+06
# 2      6.597531e+06
# 3      5.592401e+06
# 4      6.164161e+06
#            ...
# 995    7.013662e+06
# 996    6.035998e+06
# 997    6.705575e+06
# 998    6.872618e+06
# 999    5.824307e+06
# Name: date, Length: 1000, dtype: float64
