# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer

# %%
df = pd.read_csv('house.csv',usecols=['GarageQual','FireplaceQu','SalePrice'])
df.head()
# Out:
#   FireplaceQu GarageQual  SalePrice
# 0         NaN         TA     208500
# 1          TA         TA     181500
# 2          TA         TA     223500
# 3          Gd         TA     140000
# 4          TA         TA     250000

# %%
df.isnull().mean()*100
# Out:
# FireplaceQu    47.260274
# GarageQual      5.547945
# SalePrice       0.000000
# dtype: float64

# %%
df['GarageQual'].value_counts().sort_values(ascending=False).plot.bar()
plt.xlabel('GarageQual')
plt.ylabel('Number of Houses')
# Out:
# Text(0, 0.5, 'Number of Houses')

# %%
df['FireplaceQu'].value_counts().sort_values(ascending=False).plot.bar()
plt.xlabel('FireplaceQu')
plt.ylabel('Number of Houses')
# Out:
# Text(0, 0.5, 'Number of Houses')

# %%
df['GarageQual'].fillna('Missing', inplace=True)
df.sample(5)
# Out:
#      FireplaceQu GarageQual  SalePrice
# 1413          Gd         TA     257000
# 138           TA         TA     230000
# 956           TA         TA     124000
# 202      Missing         TA     112000
# 477           Gd         TA     380000

# %%
df['FireplaceQu'].fillna('Missing', inplace=True)
df.sample(5)
# Out:
#      FireplaceQu GarageQual  SalePrice
# 371           Gd         TA     134432
# 1318          TA         TA     275000
# 1383     Missing         TA     112000
# 1071     Missing         TA     154000
# 500      Missing         TA     113000

# %%
df['GarageQual'].value_counts().sort_values(ascending=False).plot.bar()
plt.xlabel('GarageQual')
plt.ylabel('Number of Houses')
# Out:
# Text(0, 0.5, 'Number of Houses')

# %%
df['FireplaceQu'].value_counts().sort_values(ascending=False).plot.bar()
plt.xlabel('FireplaceQu')
plt.ylabel('Number of Houses')
# Out:
# Text(0, 0.5, 'Number of Houses')

# %%
#SKLEARN

# %%
X_train,X_test,y_train,y_test = train_test_split(df.drop(columns=['SalePrice']),df['SalePrice'],test_size=0.2)

# %%
imputer1 = SimpleImputer(strategy='constant',fill_value='Missing')

# %%
X_train=imputer1.fit(X_train)
X_test=imputer1.fit_transform(X_test)

# %%
imputer1.statistics_
# Out:
# array(['Missing', 'Missing'], dtype=object)

# %%
X_train
# Out:
# SimpleImputer(fill_value='Missing', strategy='constant')

# %%
X_test
# Out:
# array([['Gd', 'TA'],
#        ['TA', 'TA'],
#        ['TA', 'TA'],
#        ['TA', 'TA'],
#        ['Missing', 'TA'],
#        ['Missing', 'TA'],
#        ['Gd', 'TA'],
#        ['Gd', 'TA'],
#        ['Missing', 'TA'],
#        ['Gd', 'TA'],
#        ['Missing', 'TA'],
#        ['Missing', 'TA'],
#        ['Gd', 'TA'],
#        ['Missing', 'TA'],
#        ['Missing', 'TA'],
#        ['TA', 'TA'],
#        ['Missing', 'TA'],
#        ['Missing', 'Fa'],
#        ['TA', 'TA'],
#        ['Missing', 'TA'],
#        ['Missing', 'TA'],
#        ['Po', 'TA'],
#        ['Gd', 'TA'],
#        ['Missing', 'TA'],
#        ['Gd', 'TA'],
#        ['Missing', 'TA'],
#        ['Missing', 'TA'],
#        ['Missing', 'TA'],
#        ['Gd', 'TA'],
#        ['Missing', 'Fa'],
#        ['Missing', 'TA'],
#        ['Missing', 'TA'],
#        ['Fa', 'TA'],
#        ['Missing', 'Fa'],
#        ['Missing', 'TA'],
#        ['Gd', 'TA'],
#        ['Missing', 'TA'],
#        ['Gd', 'TA'],
#        ['Missing', 'TA'],
#        ['Missing', 'TA'],
#        ['Ex', 'TA'],
#        ['Gd', 'Fa'],
#        ['Gd', 'TA'],
#        ['Missing', 'TA'],
#        ['TA', 'Gd'],
#        ['Gd', 'TA'],
#        ['Missing', 'TA'],
#        ['Missing', 'TA'],
#        ['Gd', 'Gd'],
#        ['Gd', 'TA'],
#        ['Missing', 'TA'],
#        ['Gd', 'TA'],
#        ['Gd', 'TA'],
#        ['Gd', 'TA'],
#        ['TA', 'TA'],
#        ['Missing', 'TA'],
#        ['Gd', 'TA'],
#        ['Missing', 'TA'],
#        ['Missing', 'TA'],
#        ['Missing', 'TA'],
#        ['Missing', 'TA'],
#        ['Missing', 'Fa'],
#        ['Gd', 'TA'],
#        ['Missing', 'TA'],
#        ['Gd', 'TA'],
#        ['Fa', 'TA'],
#        ['Gd', 'TA'],
#        ['Missing', 'TA'],
#        ['Missing', 'TA'],
#        ['Fa', 'TA'],
#        ['TA', 'TA'],
#        ['Missing', 'TA'],
#        ['TA', 'TA'],
#        ['Gd', 'TA'],
#        ['Missing', 'TA'],
#        ['Gd', 'TA'],
#        ['Fa', 'TA'],
#        ['Gd', 'TA'],
#        ['TA', 'TA'],
#        ['Missing', 'TA'],
#        ['Gd', 'TA'],
#        ['TA', 'TA'],
#        ['Missing', 'TA'],
#        ['Missing', 'TA'],
#        ['Gd', 'TA'],
#        ['Missing', 'TA'],
#        ['Missing', 'TA'],
#        ['Missing', 'TA'],
#        ['Gd', 'TA'],
#        ['Gd', 'TA'],
#        ['TA', 'TA'],
#        ['Po', 'TA'],
#        ['Missing', 'TA'],
#        ['Missing', 'TA'],
#        ['Missing', 'TA'],
#        ['Po', 'TA'],
#        ['TA', 'TA'],
#        ['Missing', 'TA'],
#        ['TA', 'TA'],
#        ['Gd', 'TA'],
#        ['Missing', 'TA'],
#        ['Fa', 'TA'],
#        ['Missing', 'Missing'],
#        ['Missing', 'TA'],
#        ['Missing', 'TA'],
#        ['Gd', 'TA'],
#        ['TA', 'Fa'],
#        ['Missing', 'Missing'],
#        ['Missing', 'TA'],
#        ['Missing', 'TA'],
#        ['Missing', 'TA'],
#        ['Missing', 'TA'],
#        ['Missing', 'TA'],
#        ['TA', 'TA'],
#        ['Gd', 'TA'],
#        ['TA', 'TA'],
#        ['Missing', 'Fa'],
#        ['Gd', 'Fa'],
#        ['TA', 'TA'],
#        ['Missing', 'Fa'],
#        ['TA', 'TA'],
#        ['Missing', 'TA'],
#        ['Missing', 'Missing'],
#        ['Missing', 'Missing'],
#        ['Ex', 'TA'],
#        ['Gd', 'TA'],
#        ['Missing', 'TA'],
#        ['TA', 'TA'],
#        ['Gd', 'TA'],
#        ['Gd', 'TA'],
#        ['Missing', 'TA'],
#        ['Fa', 'TA'],
#        ['Gd', 'TA'],
#        ['TA', 'TA'],
#        ['TA', 'TA'],
#        ['Missing', 'TA'],
#        ['Gd', 'TA'],
#        ['Gd', 'TA'],
#        ['Missing', 'Fa'],
#        ['Gd', 'TA'],
#        ['TA', 'TA'],
#        ['Missing', 'TA'],
#        ['TA', 'TA'],
#        ['Missing', 'TA'],
#        ['Missing', 'TA'],
#        ['Gd', 'TA'],
#        ['Missing', 'TA'],
#        ['Missing', 'TA'],
#        ['TA', 'TA'],
#        ['Gd', 'TA'],
#        ['Missing', 'TA'],
#        ['Gd', 'Fa'],
#        ['TA', 'TA'],
#        ['Gd', 'TA'],
#        ['Missing', 'Missing'],
#        ['Gd', 'Ex'],
#        ['Missing', 'TA'],
#        ['Missing', 'TA'],
#        ['Gd', 'TA'],
#        ['Missing', 'Missing'],
#        ['TA', 'TA'],
#        ['TA', 'TA'],
#        ['Gd', 'TA'],
#        ['Missing', 'TA'],
#        ['Missing', 'Missing'],
#        ['TA', 'TA'],
#        ['Missing', 'TA'],
#        ['Missing', 'Missing'],
#        ['Missing', 'Missing'],
#        ['TA', 'TA'],
#        ['TA', 'TA'],
#        ['TA', 'Ex'],
#        ['Missing', 'TA'],
#        ['Gd', 'TA'],
#        ['Missing', 'TA'],
#        ['Missing', 'TA'],
#        ['Missing', 'TA'],
#        ['TA', 'TA'],
#        ['Gd', 'TA'],
#        ['TA', 'TA'],
#        ['Gd', 'Fa'],
#        ['Missing', 'TA'],
#        ['Missing', 'TA'],
#        ['Missing', 'TA'],
#        ['Missing', 'TA'],
#        ['TA', 'TA'],
#        ['Missing', 'Fa'],
#        ['Missing', 'TA'],
#        ['Missing', 'TA'],
#        ['Missing', 'TA'],
#        ['Missing', 'Missing'],
#        ['TA', 'TA'],
#        ['Missing', 'TA'],
#        ['Gd', 'TA'],
#        ['Missing', 'TA'],
#        ['Ex', 'TA'],
#        ['Fa', 'TA'],
#        ['Missing', 'TA'],
#        ['Gd', 'TA'],
#        ['Missing', 'TA'],
#        ['Missing', 'TA'],
#        ['TA', 'TA'],
#        ['Gd', 'TA'],
#        ['TA', 'TA'],
#        ['Gd', 'TA'],
#        ['Missing', 'TA'],
#        ['TA', 'TA'],
#        ['Missing', 'TA'],
#        ['Missing', 'TA'],
#        ['Missing', 'TA'],
#        ['Missing', 'TA'],
#        ['Missing', 'TA'],
#        ['Gd', 'TA'],
#        ['Gd', 'TA'],
#        ['Missing', 'TA'],
#        ['Missing', 'TA'],
#        ['Missing', 'TA'],
#        ['Gd', 'TA'],
#        ['TA', 'TA'],
#        ['Missing', 'TA'],
#        ['Missing', 'TA'],
#        ['Missing', 'TA'],
#        ['TA', 'TA'],
#        ['Missing', 'TA'],
#        ['Missing', 'TA'],
#        ['Gd', 'TA'],
#        ['Gd', 'TA'],
#        ['Missing', 'TA'],
#        ['Ex', 'TA'],
#        ['Missing', 'TA'],
#        ['TA', 'TA'],
#        ['Missing', 'TA'],
#        ['Missing', 'TA'],
#        ['TA', 'TA'],
#        ['Missing', 'TA'],
#        ['Gd', 'TA'],
#        ['Missing', 'TA'],
#        ['Gd', 'TA'],
#        ['Missing', 'TA'],
#        ['Missing', 'TA'],
#        ['TA', 'TA'],
#        ['Gd', 'TA'],
#        ['TA', 'TA'],
#        ['Missing', 'TA'],
#        ['TA', 'TA'],
#        ['Missing', 'TA'],
#        ['TA', 'TA'],
#        ['Missing', 'TA'],
#        ['TA', 'TA'],
#        ['Gd', 'TA'],
#        ['Gd', 'TA'],
#        ['Gd', 'TA'],
#        ['Missing', 'TA'],
#        ['Gd', 'TA'],
#        ['Missing', 'TA'],
#        ['Fa', 'TA'],
#        ['Missing', 'TA'],
#        ['Gd', 'TA'],
#        ['Gd', 'TA'],
#        ['Missing', 'TA'],
#        ['Missing', 'TA'],
#        ['TA', 'TA'],
#        ['TA', 'Fa'],
#        ['Gd', 'TA'],
#        ['Gd', 'TA'],
#        ['Gd', 'TA'],
#        ['Missing', 'TA'],
#        ['Missing', 'TA'],
#        ['Missing', 'Fa'],
#        ['Gd', 'TA'],
#        ['Gd', 'TA'],
#        ['Missing', 'TA'],
#        ['TA', 'TA'],
#        ['Missing', 'TA'],
#        ['Gd', 'TA'],
#        ['TA', 'TA'],
#        ['Gd', 'TA'],
#        ['Missing', 'Missing'],
#        ['Missing', 'Missing'],
#        ['TA', 'TA'],
#        ['Missing', 'TA'],
#        ['Missing', 'TA'],
#        ['Gd', 'TA'],
#        ['Gd', 'TA'],
#        ['Missing', 'TA'],
#        ['TA', 'TA'],
#        ['Ex', 'TA'],
#        ['Missing', 'Missing'],
#        ['TA', 'TA'],
#        ['Missing', 'TA'],
#        ['Missing', 'TA'],
#        ['TA', 'TA']], dtype=object)
