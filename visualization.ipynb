# %%
# !pip install dtreeviz

# %%
import graphviz.backend as be

# %%
from sklearn.tree import DecisionTreeClassifier
from graphviz.backend import run, view
from dtreeviz.trees import *
from IPython.display import Image, display_svg, SVG
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 2
#       1 from sklearn.tree import DecisionTreeClassifier
# ----> 2 from graphviz.backend import run, view
#       3 from dtreeviz.trees import *
#       4 from IPython.display import Image, display_svg, SVG
#
# ImportError: cannot import name 'run' from 'graphviz.backend' (C:\Users\laiba\anaconda3\envs\newenv\Lib\site-packages\graphviz\backend\__init__.py)

# %%
clas = tree.DecisionTreeClassifier(max_depth=2)
iris = load_iris()

X_train = iris.data
y_train = iris.target
clas.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 clas = tree.DecisionTreeClassifier(max_depth=2)
#       2 iris = load_iris()
#       4 X_train = iris.data
#
# NameError: name 'tree' is not defined

# %%
from sklearn.tree import plot_tree
plot_tree(clas)

# %%
viz = dtreeviz(clas, X_train, y_train, feature_names=iris.feature_names, class_name=["setos","versicolor", "virginica"])

# %%
viz

# %%
viz = dtreeviz(clas, X_train, y_train, feature_names=iris.feature_names, class_name=["setos","versicolor", "virginica"], scale=2)
viz
