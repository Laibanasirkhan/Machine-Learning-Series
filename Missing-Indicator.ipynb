# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split

from sklearn.impute import MissingIndicator,SimpleImputer

# %%
df = pd.read_csv('train.csv',usecols=['Age','Fare','Survived'])

# %%
df.head()
# Out:
#    Survived   Age     Fare
# 0         0  22.0   7.2500
# 1         1  38.0  71.2833
# 2         1  26.0   7.9250
# 3         1  35.0  53.1000
# 4         0  35.0   8.0500

# %%
df.isnull().mean()*100
# Out:
# Survived     0.00000
# Age         19.86532
# Fare         0.00000
# dtype: float64

# %%
X = df.drop(columns=['Survived'])
y = df['Survived']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
X_train.head()
# Out:
#       Age     Fare
# 30   40.0  27.7208
# 10    4.0  16.7000
# 873  47.0   9.0000
# 182   9.0  31.3875
# 876  20.0   9.8458

# %%
X_train['Age_imputed'] = X_train['Age']
X_test['Age_imputed'] = X_test['Age']
X_train.tail()
# Out:
#       Age      Fare  Age_imputed
# 534  30.0    8.6625         30.0
# 584   NaN    8.7125          NaN
# 493  71.0   49.5042         71.0
# 527   NaN  221.7792          NaN
# 168   NaN   25.9250          NaN

# %%
#random impuation
X_train['Age_imputed'][X_train['Age_imputed'].isnull()] = X_train['Age'].dropna().sample(X_train['Age'].isnull().sum()).values
X_test['Age_imputed'][X_test['Age_imputed'].isnull()] = X_test['Age'].dropna().sample(X_test['Age'].isnull().sum()).values
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\envs\newenv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:173, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '30     False
# 10     False
# 873    False
# 182    False
# 876    False
#        ...
# 534    False
# 584    False
# 493    False
# 527    False
# 168    False
# Name: Age_imputed, Length: 712, dtype: bool' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# File ~\anaconda3\envs\newenv\Lib\site-packages\pandas\core\series.py:1298, in Series.__setitem__(self, key, value)
#    1297 try:
# -> 1298     self._set_with_engine(key, value, warn=warn)
#    1299 except KeyError:
#    1300     # We have a scalar (or for MultiIndex or object-dtype, scalar-like)
#    1301     #  key that is not present in self.index.
#
# File ~\anaconda3\envs\newenv\Lib\site-packages\pandas\core\series.py:1370, in Series._set_with_engine(self, key, value, warn)
#    1369 def _set_with_engine(self, key, value, warn: bool = True) -> None:
# -> 1370     loc = self.index.get_loc(key)
#    1372     # this is equivalent to self._values[key] = value
#
# File ~\anaconda3\envs\newenv\Lib\site-packages\pandas\core\indexes\base.py:3817, in Index.get_loc(self, key)
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
# -> 3817     self._check_indexing_error(key)
#    3818     raise
#
# File ~\anaconda3\envs\newenv\Lib\site-packages\pandas\core\indexes\base.py:6059, in Index._check_indexing_error(self, key)
#    6056 if not is_scalar(key):
#    6057     # if key is not a scalar, directly raise an error (the code below
#    6058     # would convert to numpy arrays and raise later any way) - GH29926
# -> 6059     raise InvalidIndexError(key)
#
# InvalidIndexError: 30     False
# 10     False
# 873    False
# 182    False
# 876    False
#        ...
# 534    False
# 584    False
# 493    False
# 527    False
# 168    False
# Name: Age_imputed, Length: 712, dtype: bool
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 X_train['Age_imputed'][X_train['Age_imputed'].isnull()] = X_train['Age'].dropna().sample(X_train['Age'].isnull().sum()).values
#       2 X_test['Age_imputed'][X_test['Age_imputed'].isnull()] = X_test['Age'].dropna().sample(X_test['Age'].isnull().sum()).values
#
# File ~\anaconda3\envs\newenv\Lib\site-packages\pandas\core\series.py:1351, in Series.__setitem__(self, key, value)
#    1341 if (
#    1342     is_list_like(value)
#    1343     and len(value) != len(self)
#    (...)   1348     #  _where call below
#    1349     # GH#44265
#    1350     indexer = key.nonzero()[0]
# -> 1351     self._set_values(indexer, value)
#    1352     return
#    1354 # otherwise with listlike other we interpret series[mask] = other
#    1355 #  as series[mask] = other[mask]
#
# File ~\anaconda3\envs\newenv\Lib\site-packages\pandas\core\series.py:1419, in Series._set_values(self, key, value, warn)
#    1416 if isinstance(key, (Index, Series)):
#    1417     key = key._values
# -> 1419 self._mgr = self._mgr.setitem(indexer=key, value=value, warn=warn)
#    1420 self._maybe_update_cacher()
#
# File ~\anaconda3\envs\newenv\Lib\site-packages\pandas\core\internals\managers.py:415, in BaseBlockManager.setitem(self, indexer, value, warn)
#     411     # No need to split if we either set all columns or on a single block
#     412     # manager
#     413     self = self.copy()
# --> 415 return self.apply("setitem", indexer=indexer, value=value)
#
# File ~\anaconda3\envs\newenv\Lib\site-packages\pandas\core\internals\managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~\anaconda3\envs\newenv\Lib\site-packages\pandas\core\internals\blocks.py:1403, in Block.setitem(self, indexer, value, using_cow)
#    1400     values = values.T
#    1402 # length checking
# -> 1403 check_setitem_lengths(indexer, value, values)
#    1405 if self.dtype != _dtype_obj:
#    1406     # GH48933: extract_array would convert a pd.Series value to np.ndarray
#    1407     value = extract_array(value, extract_numpy=True)
#
# File ~\anaconda3\envs\newenv\Lib\site-packages\pandas\core\indexers\utils.py:166, in check_setitem_lengths(indexer, value, values)
#     160         indexer = np.array(indexer)
#     161     if not (
#     162         isinstance(indexer, np.ndarray)
#     163         and indexer.dtype == np.bool_
#     164         and indexer.sum() == len(value)
#     165     ):
# --> 166         raise ValueError(
#     167             "cannot set using a list-like indexer "
#     168             "with a different length than the value"
#     169         )
#     170 if not len(indexer):
#     171     no_op = True
#
# ValueError: cannot set using a list-like indexer with a different length than the value

# %%
X_train
# Out:
#       Age      Fare  Age_imputed
# 30   40.0   27.7208         40.0
# 10    4.0   16.7000          4.0
# 873  47.0    9.0000         47.0
# 182   9.0   31.3875          9.0
# 876  20.0    9.8458         20.0
# ..    ...       ...          ...
# 534  30.0    8.6625         30.0
# 584   NaN    8.7125         22.0
# 493  71.0   49.5042         71.0
# 527   NaN  221.7792         51.0
# 168   NaN   25.9250         40.0
#
# [712 rows x 3 columns]

# %%
si = SimpleImputer()
X_train_trf = si.fit_transform(X_train)
X_test_trf = si.transform(X_test)

# %%
X_train_trf
# Out:
# array([[ 40.        ,  27.7208    ,  40.        ],
#        [  4.        ,  16.7       ,   4.        ],
#        [ 47.        ,   9.        ,  47.        ],
#        ...,
#        [ 71.        ,  49.5042    ,  71.        ],
#        [ 29.78590426, 221.7792    ,  51.        ],
#        [ 29.78590426,  25.925     ,  40.        ]], shape=(712, 3))

# %%
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression()

clf.fit(X_train_trf,y_train)

y_pred = clf.predict(X_test_trf)

from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.6089385474860335

# %%
mi = MissingIndicator()

mi.fit(X_train)
# Out:
# MissingIndicator()

# %%
mi.features_
# Out:
# array([0])

# %%
X_train_missing = mi.transform(X_train)

# %%
X_train_missing.shape
# Out:
# (712, 1)

# %%
X_test_missing = mi.transform(X_test)

# %%
X_test_missing.shape
# Out:
# (179, 1)

# %%
X_train['Age_NA'] = X_train_missing

# %%
X_test
# Out:
#       Age     Fare
# 707  42.0  26.2875
# 37   21.0   8.0500
# 615  24.0  65.0000
# 169  28.0  56.4958
# 68   17.0   7.9250
# ..    ...      ...
# 89   24.0   8.0500
# 80   22.0   9.0000
# 846   NaN  69.5500
# 870  26.0   7.8958
# 251  29.0  10.4625
#
# [179 rows x 2 columns]

# %%
X_test['Age_NA'] = X_test_missing

# %%
X_train
# Out:
#       Age      Fare  Age_imputed  Age_NA
# 30   40.0   27.7208         40.0   False
# 10    4.0   16.7000          4.0   False
# 873  47.0    9.0000         47.0   False
# 182   9.0   31.3875          9.0   False
# 876  20.0    9.8458         20.0   False
# ..    ...       ...          ...     ...
# 534  30.0    8.6625         30.0   False
# 584   NaN    8.7125         22.0    True
# 493  71.0   49.5042         71.0   False
# 527   NaN  221.7792         51.0    True
# 168   NaN   25.9250         40.0    True
#
# [712 rows x 4 columns]

# %%
si = SimpleImputer()

X_train_trf2 = si.fit_transform(X_train)
X_test_trf2 = si.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression()

clf.fit(X_train_trf2,y_train)

y_pred = clf.predict(X_test_trf2)

from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.6312849162011173

# %%
si = SimpleImputer(add_indicator=True)

# %%
X_train = si.fit_transform(X_train)

# %%
X_test = si.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression()

clf.fit(X_train_trf2,y_train)

y_pred = clf.predict(X_test_trf2)

from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.6312849162011173
